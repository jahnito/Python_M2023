# %%
import pandas as pd
import numpy as np

# %%
'''
Загрузить со страницы таблицу со странами Восточной Европы и вывести названия и столицы государств Восточной Европы.
'''

wiki_table = pd.read_html('https://ru.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B8%D1%81%D0%BE%D0%BA_%D0%B3%D0%BE%D1%81%D1%83%D0%B4%D0%B0%D1%80%D1%81%D1%82%D0%B2_%D0%B8_%D0%B7%D0%B0%D0%B2%D0%B8%D1%81%D0%B8%D0%BC%D1%8B%D1%85_%D1%82%D0%B5%D1%80%D1%80%D0%B8%D1%82%D0%BE%D1%80%D0%B8%D0%B9_%D0%95%D0%B2%D1%80%D0%BE%D0%BF%D1%8B')
wiki_table[1]
# Out:
#      Название (Официальное название)  Флаг     Столица   Официальный язык(и)  \
# 0   Белоруссия (Республика Беларусь)   NaN       Минск  Белорусский; русский
# 1     Болгария (Республика Болгария)   NaN       София            Болгарский
# 2                  Венгрия (Венгрия)   NaN    Будапешт            Венгерский
# 3      Молдавия (Республика Молдова)   NaN     Кишинёв         Румынский[21]
# 4         Польша (Республика Польша)   NaN     Варшава              Польский
# 5  Россия[22] (Российская Федерация)   NaN      Москва               Русский
# 6                  Румыния (Румыния)   NaN    Бухарест             Румынский
# 7    Словакия (Словацкая Республика)   NaN  Братислава             Словацкий
# 8                  Украина (Украина)   NaN        Киев            Украинский
# 9         Чехия (Чешская Республика)   NaN       Прага               Чешский
#
#     Денежная единица Площадь км²Место в мире  \
# 0  Белорусский рубль               207 60084
# ...

# %%
'''
Определить количество строк и столбцов в загруженной таблице.
'''
print(f'Количество строк {len(wiki_table[1].index)}')
print(f'Количество столбцов {len(wiki_table[1].columns)}')
# Out:
# Количество строк 10
# Количество столбцов 9
